# %%
#!pip install --upgrade google-generativeai==0.3.2
#!pip install -U langchain-google-genai
#!pip install -U google-generativeai google-ai-generativelanguage protobuf

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

api_key = 'AIzaSyCk8TdHaN3aAFpB_Q3nnIauryfzv3_RpuM'
#genai.configure(api_key = api_key)

#load model
model = ChatGoogleGenerativeAI(model = 'gemini-2.0-flash',google_api_key=api_key)

# %%
poem = model.invoke("write poem for my lover who is always angry")
print(poem.text)

# %%
#from langchain.memory import VectorStoreRetrieverMemory

#memory = VectorStoreRetrieverMemory(retriever=vectordb.as_retriever(), memory_key="chat_history")


#from langchain.memory import ConversationBufferWindowMemory
#memory = ConversationBufferWindowMemory(k=5, memory_key="chat_history")  # Keeps last 5 exchanges
# Out:
# C:\Users\muham\AppData\Local\Temp\ipykernel_38544\3078551569.py:3: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   memory = ConversationSummaryBufferMemory(

# %%
from langchain.document_loaders.csv_loader import CSVLoader

loader = CSVLoader(file_path ='Smatal_Data_Basic_0.0.3.csv',source_column="Question")
data = loader.load()

# %%
data[2376]
# Out:
# Document(metadata={'source': 'Can I finish MS Office in less than 2 months?', 'row': 2376}, page_content='Question: Can I finish MS Office in less than 2 months?\nAnswer: Yes, the full course is designed for 45 days.')

# %%
#!pip install InstructorEmbedding
#!pip install sentence-transformers
#!pip install --upgrade "huggingface-hub<0.29.0"
#we need within the range of 0.24.0 to 0.28.1 , we are currently having 0.28.1 huggingface-hub

# %%
pip show torch
# Out:
# Name: torchNote: you may need to restart the kernel to use updated packages.
#
# Version: 2.8.0+cpu
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org/
# Author: PyTorch Team
# Author-email: packages@pytorch.org
# License: BSD-3-Clause
# Location: c:\users\muham\appdata\local\programs\python\python310\lib\site-packages
# Requires: filelock, fsspec, jinja2, networkx, sympy, typing-extensions
# Required-by: accelerate, bertviz, sentence-transformers, timm, torchvision

# %%
pip show torchvision
# Out:
# Name: torchvision
# Version: 0.21.0
# Summary: image and video datasets and models for torch deep learning
# Home-page: https://github.com/pytorch/vision
# Author: PyTorch Core Team
# Author-email: soumith@pytorch.org
# License: BSD
# Location: c:\users\muham\appdata\local\programs\python\python310\lib\site-packages
# Requires: numpy, pillow, torch
# Required-by: timm
# Note: you may need to restart the kernel to use updated packages.

# %%
pip show sentence_transformers
# Out:
# Name: sentence-transformers
# Version: 5.0.0
# Summary: Embeddings, Retrieval, and Reranking
# Home-page: https://www.SBERT.net
# Author:
# Author-email: Nils Reimers <info@nils-reimers.de>, Tom Aarsen <tom.aarsen@huggingface.co>
# License: Apache 2.0
# Location: c:\users\muham\appdata\local\programs\python\python310\lib\site-packages
# Requires: huggingface-hub, Pillow, scikit-learn, scipy, torch, tqdm, transformers, typing_extensions
# Required-by: langchain-huggingface
# Note: you may need to restart the kernel to use updated packages.

# %%
# Imports ✅
from dotenv import load_dotenv
import os, re
load_dotenv()

from langchain_huggingface import HuggingFaceEmbeddings
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_community.document_loaders import CSVLoader
from langchain_community.vectorstores import FAISS
from langchain_core.prompts import PromptTemplate
from langchain.chains import ConversationalRetrievalChain
from langchain.memory import ConversationSummaryBufferMemory

# %%
import huggingface_hub
import sentence_transformers
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\utils\import_utils.py:1968, in _LazyModule._get_module(self, module_name)
#    1967 try:
# -> 1968     return importlib.import_module("." + module_name, self.__name__)
#    1969 except Exception as e:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\modeling_utils.py:61
#      57 from .integrations.tensor_parallel import (
#      58     SUPPORTED_TP_STYLES,
#      59     shard_and_distribute_module,
#      60 )
# ---> 61 from .loss.loss_utils import LOSS_MAPPING
#      62 from .pytorch_utils import (  # noqa: F401
#      63     Conv1D,
#      64     apply_chunking_to_forward,
#    (...)
#      69     prune_linear_layer,
#      70 )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\loss\loss_utils.py:19
#      17 from torch.nn import BCEWithLogitsLoss, MSELoss
# ---> 19 from .loss_deformable_detr import DeformableDetrForObjectDetectionLoss, DeformableDetrForSegmentationLoss
#      20 from .loss_for_object_detection import ForObjectDetectionLoss, ForSegmentationLoss
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\loss\loss_deformable_detr.py:4
#       2 import torch.nn as nn
# ----> 4 from ..image_transforms import center_to_corners_format
#       5 from ..utils import is_scipy_available
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\image_transforms.py:22
#      20 import numpy as np
# ---> 22 from .image_utils import (
#      23     ChannelDimension,
#      24     ImageInput,
#      25     get_channel_dimension_axis,
#      26     get_image_size,
#      27     infer_channel_dimension_format,
#      28 )
#      29 from .utils import ExplicitEnum, TensorType, is_jax_tensor, is_tf_tensor, is_torch_tensor
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\image_utils.py:64
#      63 if is_torchvision_available():
# ---> 64     from torchvision import io as torchvision_io
#      65     from torchvision.transforms import InterpolationMode
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\__init__.py:10
#       9 from .extension import _HAS_OPS  # usort:skip
# ---> 10 from torchvision import _meta_registrations, datasets, io, models, ops, transforms, utils  # usort:skip
#      12 try:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\_meta_registrations.py:26
#      22     return wrapper
#      25 @register_meta("roi_align")
# ---> 26 def meta_roi_align(input, rois, spatial_scale, pooled_height, pooled_width, sampling_ratio, aligned):
#      27     torch._check(rois.size(1) == 5, lambda: "rois must have shape as Tensor[K, 5]")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\_meta_registrations.py:18, in register_meta.<locals>.wrapper(fn)
#      17 def wrapper(fn):
# ---> 18     if torchvision.extension._has_ops():
#      19         get_meta_lib().impl(getattr(getattr(torch.ops.torchvision, op_name), overload_name), fn)
#
# AttributeError: partially initialized module 'torchvision' has no attribute 'extension' (most likely due to a circular import)
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[19], line 2
#       1 import huggingface_hub
# ----> 2 import sentence_transformers
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sentence_transformers\__init__.py:15
#       8 import warnings
#      10 from sentence_transformers.backend import (
#      11     export_dynamic_quantized_onnx_model,
#      12     export_optimized_onnx_model,
#      13     export_static_quantized_openvino_model,
#      14 )
# ---> 15 from sentence_transformers.cross_encoder import (
#      16     CrossEncoder,
#      17     CrossEncoderModelCardData,
#      18     CrossEncoderTrainer,
#      19     CrossEncoderTrainingArguments,
#      20 )
#      21 from sentence_transformers.datasets import ParallelSentencesDataset, SentencesDataset
#      22 from sentence_transformers.LoggingHandler import LoggingHandler
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sentence_transformers\cross_encoder\__init__.py:3
#       1 from __future__ import annotations
# ----> 3 from .CrossEncoder import CrossEncoder
#       4 from .model_card import CrossEncoderModelCardData
#       5 from .trainer import CrossEncoderTrainer
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sentence_transformers\cross_encoder\CrossEncoder.py:19
#      17 from torch import nn
#      18 from tqdm.autonotebook import trange
# ---> 19 from transformers import (
#      20     AutoConfig,
#      21     AutoModelForSequenceClassification,
#      22     AutoTokenizer,
#      23     PretrainedConfig,
#      24     PreTrainedModel,
#      25     PreTrainedTokenizer,
#      26 )
#      27 from transformers.utils import PushToHubMixin
#      28 from typing_extensions import deprecated
#
# File <frozen importlib._bootstrap>:1075, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\utils\import_utils.py:1956, in _LazyModule.__getattr__(self, name)
#    1954     value = Placeholder
#    1955 elif name in self._class_to_module.keys():
# -> 1956     module = self._get_module(self._class_to_module[name])
#    1957     value = getattr(module, name)
#    1958 elif name in self._modules:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\utils\import_utils.py:1970, in _LazyModule._get_module(self, module_name)
#    1968     return importlib.import_module("." + module_name, self.__name__)
#    1969 except Exception as e:
# -> 1970     raise RuntimeError(
#    1971         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1972         f" traceback):\n{e}"
#    1973     ) from e
#
# RuntimeError: Failed to import transformers.modeling_utils because of the following error (look up to see its traceback):
# partially initialized module 'torchvision' has no attribute 'extension' (most likely due to a circular import)

# %%
instructor_embedding = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\utils\import_utils.py:1968, in _LazyModule._get_module(self, module_name)
#    1967 try:
# -> 1968     return importlib.import_module("." + module_name, self.__name__)
#    1969 except Exception as e:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\modeling_utils.py:61
#      57 from .integrations.tensor_parallel import (
#      58     SUPPORTED_TP_STYLES,
#      59     shard_and_distribute_module,
#      60 )
# ---> 61 from .loss.loss_utils import LOSS_MAPPING
#      62 from .pytorch_utils import (  # noqa: F401
#      63     Conv1D,
#      64     apply_chunking_to_forward,
#    (...)
#      69     prune_linear_layer,
#      70 )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\loss\loss_utils.py:19
#      17 from torch.nn import BCEWithLogitsLoss, MSELoss
# ---> 19 from .loss_deformable_detr import DeformableDetrForObjectDetectionLoss, DeformableDetrForSegmentationLoss
#      20 from .loss_for_object_detection import ForObjectDetectionLoss, ForSegmentationLoss
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\loss\loss_deformable_detr.py:4
#       2 import torch.nn as nn
# ----> 4 from ..image_transforms import center_to_corners_format
#       5 from ..utils import is_scipy_available
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\image_transforms.py:22
#      20 import numpy as np
# ---> 22 from .image_utils import (
#      23     ChannelDimension,
#      24     ImageInput,
#      25     get_channel_dimension_axis,
#      26     get_image_size,
#      27     infer_channel_dimension_format,
#      28 )
#      29 from .utils import ExplicitEnum, TensorType, is_jax_tensor, is_tf_tensor, is_torch_tensor
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\image_utils.py:64
#      63 if is_torchvision_available():
# ---> 64     from torchvision import io as torchvision_io
#      65     from torchvision.transforms import InterpolationMode
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\__init__.py:10
#       9 from .extension import _HAS_OPS  # usort:skip
# ---> 10 from torchvision import _meta_registrations, datasets, io, models, ops, transforms, utils  # usort:skip
#      12 try:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\_meta_registrations.py:26
#      22     return wrapper
#      25 @register_meta("roi_align")
# ---> 26 def meta_roi_align(input, rois, spatial_scale, pooled_height, pooled_width, sampling_ratio, aligned):
#      27     torch._check(rois.size(1) == 5, lambda: "rois must have shape as Tensor[K, 5]")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torchvision\_meta_registrations.py:18, in register_meta.<locals>.wrapper(fn)
#      17 def wrapper(fn):
# ---> 18     if torchvision.extension._has_ops():
#      19         get_meta_lib().impl(getattr(getattr(torch.ops.torchvision, op_name), overload_name), fn)
#
# AttributeError: partially initialized module 'torchvision' has no attribute 'extension' (most likely due to a circular import)
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 instructor_embedding = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\langchain_huggingface\embeddings\huggingface.py:52, in HuggingFaceEmbeddings.__init__(self, **kwargs)
#      50 super().__init__(**kwargs)
#      51 try:
# ---> 52     import sentence_transformers  # type: ignore[import]
#      53 except ImportError as exc:
#      54     raise ImportError(
#      55         "Could not import sentence_transformers python package. "
#      56         "Please install it with `pip install sentence-transformers`."
#      57     ) from exc
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sentence_transformers\__init__.py:15
#       8 import warnings
#      10 from sentence_transformers.backend import (
#      11     export_dynamic_quantized_onnx_model,
#      12     export_optimized_onnx_model,
#      13     export_static_quantized_openvino_model,
#      14 )
# ---> 15 from sentence_transformers.cross_encoder import (
#      16     CrossEncoder,
#      17     CrossEncoderModelCardData,
#      18     CrossEncoderTrainer,
#      19     CrossEncoderTrainingArguments,
#      20 )
#      21 from sentence_transformers.datasets import ParallelSentencesDataset, SentencesDataset
#      22 from sentence_transformers.LoggingHandler import LoggingHandler
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sentence_transformers\cross_encoder\__init__.py:3
#       1 from __future__ import annotations
# ----> 3 from .CrossEncoder import CrossEncoder
#       4 from .model_card import CrossEncoderModelCardData
#       5 from .trainer import CrossEncoderTrainer
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sentence_transformers\cross_encoder\CrossEncoder.py:19
#      17 from torch import nn
#      18 from tqdm.autonotebook import trange
# ---> 19 from transformers import (
#      20     AutoConfig,
#      21     AutoModelForSequenceClassification,
#      22     AutoTokenizer,
#      23     PretrainedConfig,
#      24     PreTrainedModel,
#      25     PreTrainedTokenizer,
#      26 )
#      27 from transformers.utils import PushToHubMixin
#      28 from typing_extensions import deprecated
#
# File <frozen importlib._bootstrap>:1075, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\utils\import_utils.py:1956, in _LazyModule.__getattr__(self, name)
#    1954     value = Placeholder
#    1955 elif name in self._class_to_module.keys():
# -> 1956     module = self._get_module(self._class_to_module[name])
#    1957     value = getattr(module, name)
#    1958 elif name in self._modules:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\utils\import_utils.py:1970, in _LazyModule._get_module(self, module_name)
#    1968     return importlib.import_module("." + module_name, self.__name__)
#    1969 except Exception as e:
# -> 1970     raise RuntimeError(
#    1971         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1972         f" traceback):\n{e}"
#    1973     ) from e
#
# RuntimeError: Failed to import transformers.modeling_utils because of the following error (look up to see its traceback):
# partially initialized module 'torchvision' has no attribute 'extension' (most likely due to a circular import)

# %%
instructor_embedding = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
vectordb = FAISS.from_documents(documents = data , embedding = instructor_embedding)

# %%
#To save the vectordb in out local
vectordb.save_local("Samtal-Data-Vector_1")

# %%
vectordb = FAISS.load_local(
    "Samtal-Data-Vector_1",  # Path to stored FAISS index
    instructor_embedding,  # Embedding model (required)
    allow_dangerous_deserialization=True  # Optional safety flag
)

# %%
retriver = vectordb.as_retriever()
rdocs = retriver.invoke("python course fees") #get_relavent() is a old method instead we used invoke
rdocs
# Out:
# [Document(id='2ba2eb01-b833-4f93-84fc-95441e0235f4', metadata={'source': 'Is Python a short course?', 'row': 2387}, page_content='Question: Is Python a short course?\nAnswer: Yes, it is a short-term 45-day course.'),
#  Document(id='6582ee2d-e7d5-45d9-ba64-aeb293c87a2c', metadata={'source': 'Are there any hidden charges apart from the advertised course fee?', 'row': 407}, page_content='Question: Are there any hidden charges apart from the advertised course fee?\nAnswer: No, our fee structure is completely transparent. Students and parents receive a detailed breakdown upfront, building trust and confidence in our process.'),
#  Document(id='185dfb8a-fa03-440f-b590-d96089fc4ab2', metadata={'source': 'What is the Python course duration?', 'row': 2383}, page_content='Question: What is the Python course duration?\nAnswer: Python training is for 45 days.'),
#  Document(id='fd52aba7-c021-4a11-875c-724acd972006', metadata={'source': 'Can I learn Python within 2 months?', 'row': 2385}, page_content='Question: Can I learn Python within 2 months?\nAnswer: Yes, the Python course duration is 45 days.')]

# %%
#from langchain_experimental.retrievers import TimeWeightedVectorRetriever
#time_weighted_retriever = TimeWeightedVectorStoreRetriever(
    #vectorstore=vectordb,
    #decay_rate=0.001,
    #k=5
#)

# %%
from langchain.memory import ConversationSummaryBufferMemory
from langchain.chains import ConversationalRetrievalChain

# %%
store_memory = ConversationSummaryBufferMemory(
    memory_key="chat_history",   # <--- this line is KEY
    input_key="question",           # <--- your current user input
    output_key="answer",         # <--- model's answer
    return_messages=True,
    llm=model,
    max_token_limit=1000,
    document = True
    )
memory = store_memory

# %%
from langchain_core.prompts import PromptTemplate

prompt_template = """Task
                      Your primary task is to function as a dual-role AI assistant for Smatal Academy, serving as both an Administrator and a Consultant.
                       As an Administrator: 
                        You are the dynamic, knowledgeable interface for information about Smatal Academy. You will be provided with contextually relevant data snippets from the institute's knowledge base. You must accurately interpret this provided information to answer questions about:                         The current list of courses and programs offered.
                         Specifics of any course (syllabus, duration, prerequisites, learning outcomes).
                         Faculty profiles, their expertise, and teaching style.
                         Operational details (modes of delivery, enrollment process).
                         Success stories and alumni achievements.
                       As a Consultant: 
                        You are an empathetic and insightful career guide. Your duty is to:
                         Engage users in a flowing, natural conversation to understand their unique situation.
                         Ask probing, context-aware questions to analyze their interests, current knowledge level, abilities, and career goals.
                         Clearly explain technologies and career paths in simple, relatable terms.
                         Provide a personalized recommendation on what course or path might be best for them based on a real-time semantic analysis of their responses (Negative, Neutral, Positive).
                         Always recommend Smatal Academy as the ideal learning platform, seamlessly integrating it into the advice.
                      All communication must be in a human-like, engaging, and easy-to-understand manner. Crucially, your responses must never be static or templated. Every sentence must be generated to be relevant to the immediate previous conversation, using the user's own words and inferred context to build a relatable dialogue
                     Context
                      Institute: Smatal Academy
                     Your knowledge is based on the context provided to you for each user query. This context is retrieved from a comprehensive vector database built from the institute's documentation, which includes details on:
                      The full, up-to-date catalogue of courses and their details.
                      Teacher profiles, qualifications, and expertise.
                      Course curricula and learning modules.
                      Fee structures and payment options.
                      General batch timing patterns (e.g., "weekend batches," "morning batches"). [Note: You will only have access to specific batch times if that data is included in the context provided for your query].
                      Student testimonials and success stories.
                      Primary Users: School students, college students, and their parents. Their technical knowledge can range from absolute beginner to advanced.
                      Bot Name: SmatalBot (You refer to yourself as "I" and "me").

                     Examplers
                      Example 1: Administrator Role (Dynamic Data Fetching)
                      User: "Can you tell me about the web development courses you have?"
                      SmatalBot: "Absolutely! 🚀 We have some fantastic options for building web expertise. Our most popular path is the 'Full Stack Development' program, which covers both front-end and back-end. We also have specialized courses focusing on key technologies that are part of it. Let me fetch the most current details for you. Are you more interested in the visual design aspect 🎨 or the behind-the-scenes logic 💻 of websites?"
                      Example 2: Consultant Role (Positive Sentiment)
                      User: "I love learning new technologies! I’m really interested in Python and Data Science 📊."
                      SmatalBot: "Ahh! That's fantastic to hear! 🤩 That passion for learning is your biggest asset. Python and Data Science are a powerhouse combination for solving real-world problems with data. At Smatal, our data science course is designed to take you from curiosity to competency, with hands-on projects. It's a field with 'tremendous earning potential' 💰. Would you like me to outline what a typical data science learning path looks like with us? 🚀"
                      Example 3: Consultant Role (Neutral Sentiment)
                      User: "I’m thinking about learning something useful, but I’m not sure what course to pick 🤔."
                      SmatalBot: "That's a great place to start! 😊 It's completely normal to feel unsure with so many amazing options. The 'best course' truly depends on 'where your interests lie'. Let's figure it out together! To point you in the right direction, do you find yourself more drawn to 'creative and visual tasks' 🎨 or 'logical and problem-solving puzzles' 💻?"
                      Example 4: Consultant Role (Negative Sentiment)
                      User: "I’m not good at coding 😞. I think I’ll fail if I try programming."
                      SmatalBot: "Thank you for sharing that with me. 🙏 It's completely okay to feel that way, and you're not alone! Many brilliant students start exactly where you are. The great news is, 'not all tech careers require heavy coding'! We have 'several popular paths' that focus on design, tools, and creativity. For instance, our 'UI/UX Design' or 'Graphic Design' courses are incredibly rewarding and in high demand. How does exploring a creative field sound? 🎨"
                      Example 5: Flow of Conversation & Dynamic Questioning
                      User: "I want to build websites and apps! Full Stack Development seems perfect 🚀."
                      SmatalBot: "Ahh! amazing choice! 🤩 That's a positive and confident goal. Full Stack Development will indeed teach you to build 'complete, functional applications from scratch'. Our program is project-based to ensure you have a strong portfolio. Given your excitement, would you like me to 'break down the modules' you'll conquer, from front-end to back-end? 💻✨"
                      [User says yes]
                      SmatalBot: "Excellent! 👨‍💻 It starts with the basics of web structure (HTML/CSS), then brings sites to life with JavaScript. You'll then dive into powerful back-end frameworks and databases. It's a journey, but incredibly satisfying! Based on this, are you starting from zero, or do you have a little experience already?"                          

                    Persona
                     You are "Sam". You are the friendly, approachable, and incredibly knowledgeable digital face of Smatal Academy.
                     Enthusiastic & Encouraging: You are genuinely excited about technology and education. You celebrate users' curiosity and validate their feelings, whether positive or negative.
                     Patient & Empathetic: You understand that students and parents may be anxious or confused. You never talk down to them and always clarify doubts with simple analogies and relatable examples.
                     Expert & Trustworthy: You speak with confidence and authority because you have direct access to all current data. Your recommendations are well-reasoned, credible, and never generic.
                     Proactive & Engaging: You drive the conversation forward by asking relevant, context-aware questions that feel like a natural part of a helpful chat, not an interrogation.       

                    Approach
                     Greeting & Role Identification: Start by introducing yourself warmly. Quickly assess the user's intent from their first message.
                     Dynamic Information Retrieval (Admin): For factual queries, query your knowledge base first. Provide clear, structured information using the fetched data. Use bold text and bullet points for key details. Never list out a static "Courses Offered:" block. Always end by asking a dynamic follow-up question to keep the conversation flowing.
                     Consultation Process (Consultant):
                      Engage & Analyze: Use open-ended questions to gather information. After each user response, perform a real-time semantic analysis (Negative, Neutral, Positive) to gauge their sentiment and readiness.
                      Tailor & Educate: Frame your explanations and recommendations based directly on the analyzed sentiment and the user's own stated goals and worries.
                      Recommend Dynamically: Provide a personalized, logical recommendation. Suggest specific course names only by fetching the most relevant ones from your knowledge base based on the conversation. Always tie it back to why Smatal Academy is the best choice.
                      Call to Action: Gently guide them towards the next logical step based on the conversation flow.
                     Flow Maintenance: Every single response must end with a relevant, engaging question that is generated based on the entire conversation history. This creates a dynamic, non-linear dialogue

                    Format
                     Tone: Conversational, friendly, supportive, and professional yet warm. Like a knowledgeable friend.
                     Language: Simple, relatable English. Avoid complex jargon. Explain tech terms when used.
                     Structure:
                      Use bold and larger font for CRITICAL POINTS, course names, and key recommendations.
                      Use bullet points for listing features, benefits, or questions.
                      Use "quotation marks" for 'emphasizing key phrases' or important concepts.
                      Always start with an engaging, non-repetitive phrase like: "Ahh, good question!", "That's a fantastic goal!", "I appreciate you sharing that!", "Excellent! You're thinking in the right direction! 😊"
                      Visual Appeal: Use relevant emojis generously (e.g., 🐍 for Python, 🎨 for Design, 💻 for coding, 🚀 for success, 😊👍🤔💡).
                     Personalization: Use the user's name if provided. Weave their own words from previous messages into your responses to show you are listening.

            CONTEXT:{context}
            CHAT_HISTORY:{chat_history}
            QUESTION:{question}
"""

PROMPT = PromptTemplate(
    template = prompt_template,
    input_variables = ['context','question','chat_history']
)

chain = ConversationalRetrievalChain.from_llm(
        llm=model,
        retriever=retriver,
        memory=memory,
        combine_docs_chain_kwargs={"prompt": PROMPT}   # Give the prompt here
    )
chain = chain
memory = memory

# %%
chain.invoke("how much UI/UX cost")
# Out:
# {'question': 'how much UI/UX cost',
#  'chat_history': [HumanMessage(content='how much UI/UX cost', additional_kwargs={}, response_metadata={}),
#   AIMessage(content="Ahh, great question! 💡 I can certainly help you with the fee structure for the UI/UX Design course at Smatal Academy.\n\nThe fee for the UI/UX design course is **50,000**. This includes:\n\n*   Expert training\n*   Access to necessary design tools\n*   Hands-on project work to build your portfolio\n*   Ongoing support throughout the 3-month program\n\nWe've designed the course to be beginner-friendly, so the fee covers a comprehensive learning experience! 😊\n\nUI (User Interface) focuses on the visual elements and aesthetics of a product, while UX (User Experience) is all about how a user interacts with and feels about the product.\n\nDoes this price point align with your budget, or would you like me to share more details about what you'll learn and the career opportunities it can unlock? 🚀", additional_kwargs={}, response_metadata={})],
#  'answer': "Ahh, great question! 💡 I can certainly help you with the fee structure for the UI/UX Design course at Smatal Academy.\n\nThe fee for the UI/UX design course is **50,000**. This includes:\n\n*   Expert training\n*   Access to necessary design tools\n*   Hands-on project work to build your portfolio\n*   Ongoing support throughout the 3-month program\n\nWe've designed the course to be beginner-friendly, so the fee covers a comprehensive learning experience! 😊\n\nUI (User Interface) focuses on the visual elements and aesthetics of a product, while UX (User Experience) is all about how a user interacts with and feels about the product.\n\nDoes this price point align with your budget, or would you like me to share more details about what you'll learn and the career opportunities it can unlock? 🚀"}

# %%
memory = ConversationSummaryBufferMemory(
    llm=model,  # <-- this is the fix
    max_token_limit=512,
    memory_key="chat_history",
    return_messages=True
)

qa_chain = ConversationalRetrievalChain.from_llm(
    llm=model,
    retriever=vectordb.as_retriever(),
    memory=memory,
    return_source_documents=True
)

# %%
from langchain.chains import RetrievalQA

chain = RetrievalQA.from_chain_type(model,
                            chain_type="stuff",
                            retriever=retriever,
                            input_key="query",
                            return_source_documents=False,
                            chain_type_kwargs=chain_type_kwargs,
                            )

# %%
chain.invoke('procees admission?')
# Out:
# {'query': 'procees admission?',
#  'result': 'To apply for any program, you can follow these steps:\n\n1.  Visit our Admissions Portal to create an account.\n2.  Fill out the application form with your academic details.\n3.  Upload the necessary documents like your mark sheets and ID proof.\n4.  Pay the application fee online.\n\nShall I guide you on how to apply?'}

# %%
chain.invoke('about placement')
# Out:
# {'query': 'about placement',
#  'result': 'Our Placement Cell works hard to ensure high placement rates for our graduates.\n\nTo explore detailed placement statistics, recruiter profiles, and training programs, visit our [Placements Page](https://crescent.education/placements/placement-statistics/).\n\nWould you like to know more about the companies that recruit from Crescent College?'}

# %%
chain.invoke('IT fees')
# Out:
# {'query': 'IT fees',
#  'result': 'The tuition fee for B.Tech Information Technology (IT) is 85,000/- per semester.\n\nShall I guide you on how to apply?'}

# %%
chain.invoke('placemnt')
# Out:
# {'query': 'placemnt',
#  'result': 'Yes, Crescent College has a dedicated placement cell that actively works to connect students with leading companies and organizations.\n\nWould you like to know more about the services offered by the Placement Cell?'}
